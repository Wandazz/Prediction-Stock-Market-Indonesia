# %%
import math
import pandas_datareader as web
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, LSTM
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')
import seaborn as sns
from pandas_datareader.data import DataReader

# %%
bbri = web.DataReader('BBRI.jk',
                    data_source='yahoo',
                    start='2003-12-23',
                    end='2020-10-22')

display(bbri.head())
display(bbri.tail())
# Out:
#              High    Low   Open  Close       Volume  Adj Close
# Date
# 2003-12-23  127.5  122.5  125.0  125.0  278485000.0   1.760418
# 2003-12-29  125.0  120.0  125.0  125.0  267980000.0   1.760418
# 2003-12-30  125.0  122.5  125.0  125.0  307350000.0   1.760418
# 2004-01-02  127.5  122.5  125.0  127.5  228115000.0   1.795627
# 2004-01-05  127.5  122.5  125.0  127.5  343335000.0   1.795627
#               High     Low    Open   Close       Volume  Adj Close
# Date
# 2020-10-19  3290.0  3230.0  3260.0  3280.0   96199300.0     3280.0
# 2020-10-20  3290.0  3210.0  3280.0  3250.0  134038300.0     3250.0
# 2020-10-21  3310.0  3230.0  3280.0  3240.0  116981800.0     3240.0
# 2020-10-22  3300.0  3200.0  3220.0  3300.0  160136600.0     3300.0
# 2020-10-23  3350.0  3270.0  3350.0  3290.0  117246500.0     3290.0

# %%
bbni = web.DataReader('BBNI.jk',
                    data_source='yahoo',
                    start='2003-12-23',
                    end='2020-10-22')

display(bbni.head())
display(bbni.tail())
# Out:
#                    High          Low  ...    Volume   Adj Close
# Date                                  ...
# 2003-12-23  1327.199951  1232.400024  ...  426687.0  728.547791
# 2003-12-29  1303.500000  1232.400024  ...  159810.0  770.579285
# 2003-12-30  1303.500000  1232.400024  ...  365506.0  728.547791
# 2004-01-02  1256.099976  1232.400024  ...   71730.0  728.547791
# 2004-01-05  1256.099976  1232.400024  ...  313290.0  728.547791
#
# [5 rows x 6 columns]
#               High     Low    Open   Close      Volume  Adj Close
# Date
# 2020-10-19  4900.0  4820.0  4850.0  4890.0  36507600.0     4890.0
# 2020-10-20  4890.0  4810.0  4870.0  4810.0  28628400.0     4810.0
# 2020-10-21  4930.0  4850.0  4850.0  4880.0  44696300.0     4880.0
# 2020-10-22  4880.0  4830.0  4830.0  4860.0  22289100.0     4860.0
# 2020-10-23  4900.0  4840.0  4860.0  4850.0  23111100.0     4850.0

# %%
bmri = web.DataReader('BMRI.jk',
                    data_source='yahoo',
                    start='2003-12-23',
                    end='2020-10-22')

display(bmri.head())
display(bmri.tail())
# Out:
#                   High         Low  ...       Volume   Adj Close
# Date                                ...
# 2003-12-23  516.234009  491.652008  ...  131619586.0  180.394806
# 2003-12-29  503.942993  491.652008  ...   25004487.0  180.394806
# 2003-12-30  503.942993  479.359985  ...   52019544.0  175.995071
# 2004-01-02  503.942993  479.359985  ...   60528616.0  175.995071
# 2004-01-05  528.526001  491.652008  ...  163827342.0  184.794632
#
# [5 rows x 6 columns]
#               High     Low    Open   Close      Volume  Adj Close
# Date
# 2020-10-19  5725.0  5575.0  5600.0  5700.0  29468100.0     5700.0
# 2020-10-20  5750.0  5600.0  5725.0  5650.0  38606600.0     5650.0
# 2020-10-21  5725.0  5475.0  5675.0  5525.0  56950900.0     5525.0
# 2020-10-22  5550.0  5400.0  5500.0  5450.0  69350700.0     5450.0
# 2020-10-23  5575.0  5475.0  5525.0  5550.0  32950100.0     5550.0

# %%
bbca = web.DataReader('bbca.JK',
                    data_source='yahoo',
                    start='2003-12-23',
                    end='2020-10-22')

display(bbca.head())
display(bbca.tail())
# Out:
#              High    Low   Open  Close      Volume   Adj Close
# Date
# 2004-06-08  900.0  875.0  875.0  887.5  99830000.0  438.253326
# 2004-06-09  912.5  875.0  887.5  900.0  58858000.0  444.425873
# 2004-06-10  900.0  887.5  900.0  900.0  33118000.0  444.425873
# 2004-06-11  900.0  887.5  887.5  900.0  27166000.0  444.425873
# 2004-06-14  900.0  875.0  900.0  887.5  31708000.0  438.253326
#                High      Low     Open    Close      Volume  Adj Close
# Date
# 2020-10-19  29500.0  28550.0  28750.0  29500.0  11374300.0    29500.0
# 2020-10-20  29400.0  28925.0  29400.0  29025.0  14999100.0    29025.0
# 2020-10-21  29325.0  28650.0  29300.0  28900.0  15588800.0    28900.0
# 2020-10-22  29000.0  28525.0  28700.0  29000.0  19374500.0    29000.0
# 2020-10-23  29200.0  28750.0  29200.0  28850.0  13265600.0    28850.0

# %%
Cimb = web.DataReader('BNGA.JK',
                    data_source='yahoo',
                    start='2003-12-23',
                    end='2020-10-22')

display(Cimb.head())
display(Cimb.tail())
# Out:
#                   High         Low  ...      Volume   Adj Close
# Date                                ...
# 2003-12-23  409.184998  395.984985  ...  14894299.0  298.425690
# 2003-12-29  409.184998  395.984985  ...   2392702.0  301.741669
# 2003-12-30  409.184998  395.984985  ...   9180452.0  298.425690
# 2004-01-02  404.785004  387.186005  ...   8231553.0  291.794495
# 2004-01-05  404.785004  387.186005  ...   7814492.0  291.794495
#
# [5 rows x 6 columns]
#              High    Low   Open  Close     Volume  Adj Close
# Date
# 2020-10-19  775.0  755.0  765.0  765.0  1353700.0      765.0
# 2020-10-20  775.0  755.0  770.0  760.0  1827700.0      760.0
# 2020-10-21  770.0  755.0  755.0  755.0  1728400.0      755.0
# 2020-10-22  765.0  745.0  755.0  750.0  2198700.0      750.0
# 2020-10-23  760.0  750.0  750.0  755.0  1147200.0      755.0

# %%
bbri['Daily Return'] = bbri['Close'].pct_change()
bbni['Daily Return'] = bbni['Close'].pct_change()
bmri['Daily Return'] = bmri['Close'].pct_change()
bbca['Daily Return'] = bbca['Close'].pct_change()
Cimb['Daily Return'] = Cimb['Close'].pct_change()

# %%
fig, axes = plt.subplots(nrows=2, ncols=2)
fig.set_figheight(8)
fig.set_figwidth(15)

bbri['Daily Return'].plot(ax=axes[0,0], legend=True, linestyle='--', marker='o')
axes[0,0].set_title(' BRI')

bbni['Daily Return'].plot(ax=axes[0,1], legend=True, linestyle='--', marker='o')
axes[0,1].set_title('BNI')

bmri['Daily Return'].plot(ax=axes[1,0], legend=True, linestyle='--', marker='o')
axes[1,0].set_title('MANDIRI')

bbca['Daily Return'].plot(ax=axes[1,1], legend=True, linestyle='--', marker='o')
axes[1,1].set_title('BCA')

fig.tight_layout()

# %%
plt.figure(figsize=(15,8))
plt.title('CIMB')
plt.plot(Cimb['Daily Return'])
plt.xlabel('Tanggal', fontsize=18)
plt.ylabel('Daily Return', fontsize=18)
plt.show()

# %%
plt.figure(figsize=(12, 12))
plt.figure
sns.distplot(bbri['Daily Return'].dropna(), bins=100, color='blue')
plt.ylabel('Daily Return')
plt.title(f'BRI')
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 1.0, 'BRI')

# %%
plt.figure(figsize=(12, 12))
plt.subplots
sns.distplot(bbni['Daily Return'].dropna(), bins=100, color='red')
plt.ylabel('Daily Return')
plt.title(f'BNI')
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 1.0, 'BNI')

# %%
plt.figure(figsize=(12, 12))
plt.subplots
sns.distplot(bmri['Daily Return'].dropna(), bins=100, color='gold')
plt.ylabel('Daily Return')
plt.title(f'MANDIRI')
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 1.0, 'MANDIRI')

# %%
plt.figure(figsize=(12, 12))
plt.subplots
sns.distplot(bbca['Daily Return'].dropna(), bins=100, color='green')
plt.ylabel('Daily Return')
plt.title(f'BCA')
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 1.0, 'BCA')

# %%
plt.figure(figsize=(12, 12))
plt.subplots
sns.distplot(Cimb['Daily Return'].dropna(), bins=100, color='brown')
plt.ylabel('Daily Return')
plt.title(f'CIMB')
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 1.0, 'CIMB')

# %%
bbri['Daily Return'].value_counts()
# Out:
#  0.000000    623
# -0.014286     14
#  0.015625     14
# -0.015873     12
#  0.016667     11
#             ...
#  0.011050      1
#  0.001603      1
#  0.058333      1
# -0.051282      1
#  0.020877      1
# Name: Daily Return, Length: 1988, dtype: int64

# %%
bbni['Daily Return'].value_counts()
# Out:
#  0.000000    939
# -0.019231      9
# -0.009259      8
#  0.012821      7
# -0.022222      7
#             ...
#  0.029762      1
#  0.023256      1
#  0.014388      1
# -0.022581      1
# -0.018293      1
# Name: Daily Return, Length: 2281, dtype: int64

# %%
bmri['Daily Return'].value_counts()
# Out:
#  0.000000    631
# -0.007692      7
#  0.006289      7
#  0.013158      7
# -0.007143      7
#             ...
# -0.034765      1
#  0.002212      1
#  0.097015      1
#  0.004329      1
# -0.002347      1
# Name: Daily Return, Length: 2496, dtype: int64

# %%
return_bbri = bbri['Daily Return'].mean() *250
return_bbri
# Out:
# 0.27456686748763226

# %%
tech_list = ['BBRI.JK', 'BBNI.JK', 'BMRI.JK','BNGA.JK','BBCA.JK']
start=('2003-12-23')
end=('2020-10-23')
for stock in tech_list: 
  globals()[stock] = DataReader(stock, 'yahoo', start, end)

# %%
closing_df = DataReader(tech_list, 'yahoo', start, end)['Close']

# %%
closing_df.head()
# Out:
# Symbols     BBRI.JK      BBNI.JK     BMRI.JK  BNGA.JK  BBCA.JK
# Date
# 2003-12-23    125.0  1232.400024  503.942993      NaN      NaN
# 2003-12-29    125.0  1303.500000  503.942993      NaN      NaN
# 2003-12-30    125.0  1232.400024  491.652008      NaN      NaN
# 2004-01-02    127.5  1232.400024  491.652008      NaN      NaN
# 2004-01-05    127.5  1232.400024  516.234009      NaN      NaN

# %%
tech_rets = closing_df.pct_change()
tech_rets.head()
# Out:
# Symbols     BBRI.JK   BBNI.JK   BMRI.JK  BNGA.JK  BBCA.JK
# Date
# 2003-12-23      NaN       NaN       NaN      NaN      NaN
# 2003-12-29     0.00  0.057692  0.000000      NaN      NaN
# 2003-12-30     0.00 -0.054545 -0.024390      NaN      NaN
# 2004-01-02     0.02  0.000000  0.000000      NaN      NaN
# 2004-01-05     0.00  0.000000  0.049999      NaN      NaN

# %%
sns.jointplot('BBRI.JK', 'BBRI.JK', tech_rets, kind='scatter', color='seagreen')
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y, data. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.jointplot('BBRI.JK', 'BBNI.JK', tech_rets, kind='scatter', color='blue')
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y, data. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.jointplot('BMRI.JK', 'BBRI.JK', tech_rets, kind='scatter', color='blue')
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y, data. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.pairplot(tech_rets, kind='reg')

# %%
sns.heatmap(tech_rets.corr(), annot=True, cmap='summer')
plt.title('Heatmap of daily returns', fontsize = 20)
# Out:
# Text(0.5, 1.0, 'Heatmap of daily returns')

# %%
sns.heatmap(closing_df.corr(), annot=True, cmap='PuBuGn')
plt.title('Heatmap of Closing', fontsize = 20)
# Out:
# Text(0.5, 1.0, 'Heatmap of Closing')

# %%
Open_df = DataReader(tech_list, 'yahoo', start, end)['Open']

# %%
sns.heatmap(Open_df.corr(), annot=True, cmap='plasma')
plt.title('Heatmap of Open', fontsize = 20)
# Out:
# Text(0.5, 1.0, 'Heatmap of Open')

# %%
plt.figure(figsize=(16,8))
plt.title('Historikal Harga Penutupan bbca')
plt.plot(bbca['Close'])
plt.xlabel('Tanggal', fontsize=18)
plt.ylabel('Harga penutup (IDR)', fontsize=18)
plt.show()

# %%
plt.figure(figsize=(16,8))
plt.title('Historikal Harga Penutupan bbni')
plt.plot(bbni['Close'])
plt.xlabel('Tahun', fontsize=18)
plt.ylabel('Harga penutup (IDR)', fontsize=18)
plt.show()

# %%
plt.figure(figsize=(16,8))
plt.title('Historikal Harga Penutupan Cimb')
plt.plot(Cimb['Close'])
plt.xlabel('Tanggal', fontsize=18)
plt.ylabel('Harga penutup (IDR)', fontsize=18)
plt.show()

# %%
plt.figure(figsize=(16,8))
plt.title('Historikal Harga Penutupan Saham')
plt.plot(bbni['Close'],label='BNI')
plt.plot(bbri['Close'],label='BRI')
plt.plot(bbca['Close'],label='BCA')
plt.plot(Cimb['Close'],label='Cimb')
plt.plot(bmri['Close'],label='MANDIRI')
plt.xlabel('Tahun', fontsize=18)
plt.ylabel('Harga penutup (IDR)', fontsize=18)
plt.legend()

# %%
bbri_MA10 = bbri.rolling(window=10).mean()

# %%
#Calculating the 20 Days simple moving average
bbri_MA20 = bbri.rolling(window=20).mean()

# %%
#Calculating the 50 Days simple moving average
bbri_MA50 = bbri.rolling(window=50).mean()

# %%
start_date = '2003-12-23'
end_date = '2020-10-22'
fig, ax = plt.subplots(figsize=(16,9))
ax.plot(bbri.loc[start_date:end_date, :].index, bbri.loc[start_date:end_date, 'Close'], label='Price')
ax.plot(bbri_MA50.loc[start_date:end_date, :].index, bbri_MA100.loc[start_date:end_date, 'Close'], label = '50-days SMA')
ax.plot(bbri_MA20.loc[start_date:end_date, :].index, bbri_MA20.loc[start_date:end_date, 'Close'], label = '20-days SMA')
ax.plot(bbri_MA10.loc[start_date:end_date, :].index, bbri_MA10.loc[start_date:end_date, 'Close'], label = '10-days SMA')
plt.title('Moving Average BNI')
ax.legend(loc='best')
ax.set_ylabel('Price in IDR')
# Out:
# Text(0, 0.5, 'Price in IDR')

# %%
bbni_MA10 = bbni.rolling(window=10).mean()

# %%
#Calculating the 20 Days simple moving average
bbni_MA20 = bbni.rolling(window=20).mean()

# %%
#Calculating the 5 Days simple moving average
bbni_MA50 = bbni.rolling(window=50).mean()

# %%
start_date = '2003-12-23'
end_date = '2020-10-22'
fig, ax = plt.subplots(figsize=(16,9))
ax.plot(bbni.loc[start_date:end_date, :].index, bbni.loc[start_date:end_date, 'Close'], label='Price')
ax.plot(bbni_MA50.loc[start_date:end_date, :].index, bbni_MA50.loc[start_date:end_date, 'Close'], label = '50-days SMA')
ax.plot(bbni_MA20.loc[start_date:end_date, :].index, bbni_MA20.loc[start_date:end_date, 'Close'], label = '20-days SMA')
ax.plot(bbni_MA10.loc[start_date:end_date, :].index, bbni_MA10.loc[start_date:end_date, 'Close'], label = '10-days SMA')
plt.title('Moving Average BNI')
ax.legend(loc='best')
ax.set_ylabel('Price in IDR')
# Out:
# Text(0, 0.5, 'Price in IDR')

# %%
bmri_MA10 = bmri.rolling(window=10).mean()

# %%
#Calculating the 20 Days simple moving average
bmri_MA20 = bmri.rolling(window=20).mean()

# %%
#Calculating the 5 Days simple moving average
bmri_MA50 = bmri.rolling(window=50).mean()

# %%
start_date = '2003-12-23'
end_date = '2020-10-22'
fig, ax = plt.subplots(figsize=(16,9))
ax.plot(bmri.loc[start_date:end_date, :].index, bmri.loc[start_date:end_date, 'Close'], label='Price')
ax.plot(bmri_MA50.loc[start_date:end_date, :].index, bmri_MA50.loc[start_date:end_date, 'Close'], label = '50-days SMA')
ax.plot(bmri_MA20.loc[start_date:end_date, :].index, bmri_MA20.loc[start_date:end_date, 'Close'], label = '20-days SMA')
ax.plot(bmri_MA10.loc[start_date:end_date, :].index, bmri_MA10.loc[start_date:end_date, 'Close'], label = '10-days SMA')
plt.title('Moving Average Mandiri')
ax.legend(loc='best')
ax.set_ylabel('Price in IDR')
# Out:
# Text(0, 0.5, 'Price in IDR')
